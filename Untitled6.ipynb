# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier

# %%
train_path = '/content/gdrive/MyDrive/LOC/jobclassinfo2.csv'
train_df = pd.read_csv(train_path)
train_df
# Out:
#     ID  JobFamily    JobFamilyDescription  JobClass  JobClassDescription  \
# 0    1          1  Accounting And Finance         1         Accountant I
# 1    2          1  Accounting And Finance         2        Accountant II
# 2    3          1  Accounting And Finance         3       Accountant III
# 3    4          1  Accounting And Finance         4        Accountant IV
# 4    5          2  Administrative Support         5      Admin Support I
# ..  ..        ...                     ...       ...                  ...
# 61  62         15         Systems Analyst        62    Systems Analyst I
# 62  63         15         Systems Analyst        63   Systems Analyst II
# 63  64         15         Systems Analyst        64  Systems Analyst III
# 64  65         15         Systems Analyst        65   Systems Analyst IV
# 65  66         15         Systems Analyst        66    Systems Analyst V
#
#     PayGrade  EducationLevel  Experience  OrgImpact  ProblemSolving  \
# ...

# %%
train_df.columns
# Out:
# Index(['ID', 'JobFamily', 'JobFamilyDescription', 'JobClass',
#        'JobClassDescription', 'PayGrade', 'EducationLevel', 'Experience',
#        'OrgImpact', 'ProblemSolving', 'Supervision', 'ContactLevel',
#        'FinancialBudget', 'PG'],
#       dtype='object')

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    66 non-null     int64
#  1   JobFamily             66 non-null     int64
#  2   JobFamilyDescription  66 non-null     object
#  3   JobClass              66 non-null     int64
#  4   JobClassDescription   66 non-null     object
#  5   PayGrade              66 non-null     int64
#  6   EducationLevel        66 non-null     int64
#  7   Experience            66 non-null     int64
#  8   OrgImpact             66 non-null     int64
#  9   ProblemSolving        66 non-null     int64
#  10  Supervision           66 non-null     int64
#  11  ContactLevel          66 non-null     int64
#  12  FinancialBudget       66 non-null     int64
#  13  PG                    66 non-null     object
# dtypes: int64(11), object(3)
# memory usage: 7.3+ KB

# %%
train_df["JobFamilyDescription"].unique()
# Out:
# array(['Accounting And Finance', 'Administrative Support', 'Baker',
#        'Buildings And Facilities', 'Buyer', 'Cashier',
#        'Communications And Media', 'Corporate Research',
#        'Finance  And Accounting', 'Human Resources', 'Meat Cutter',
#        'Produce', 'Secretary', 'Stockkeeping', 'Systems Analyst'],
#       dtype=object)

# %%
label = LabelEncoder()

a = train_df['JobFamilyDescription'].to_numpy()
b = train_df['JobClassDescription'].to_numpy()
c = train_df['PG'].to_numpy()

train_df.drop(['JobFamilyDescription','JobClassDescription','PG','ID'],axis=1, inplace=True)

train_df['JobFamilyDescription'] = label.fit_transform(a)
train_df['JobClassDescription'] = label.fit_transform(b)
train_df['PG'] = label.fit_transform(c)
train_df
# Out:
#     JobFamily  JobClass  PayGrade  EducationLevel  Experience  OrgImpact  \
# 0           1         1         5               3           1          3
# 1           1         2         6               4           1          5
# 2           1         3         8               4           2          6
# 3           1         4        10               5           5          6
# 4           2         5         1               1           0          1
# ..        ...       ...       ...             ...         ...        ...
# 61         15        62         3               1           1          1
# 62         15        63         5               4           1          3
# 63         15        64         6               5           2          4
# 64         15        65         8               5           5          6
# 65         15        66        10               5           5          6
#
#     ProblemSolving  Supervision  ContactLevel  FinancialBudget  \
# ...

# %%
X_train, X_test, y_train, y_test=train_test_split(train_df,train_df['JobFamilyDescription'],test_size=0.3,random_state=42)

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
y_train = y_train.to_numpy()
y_test = y_test.to_numpy()

# %%
dct = DecisionTreeClassifier()
dct.fit(X_train,y_train)
print(dct.score(X_train,y_train))
print(dct.score(X_test,y_test))
# Out:
# 1.0
# 0.9
